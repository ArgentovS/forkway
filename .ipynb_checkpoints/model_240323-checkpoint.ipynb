# %% [markdown]
# **ПОСТРОЕНИЕ МОДЕЛИ МАШИННОГО ОБУЧЕНИЯ,
# ОПРЕДЕЛЯЮЩЕЙ ТРЕБУЕМЫЕ ОТ ПРЕТЕНДЕНТА НАВЫКИ В ТЕКСТЕ ОБЪЯВЛЕНИЯ НА ВКАНСИЮ**
#
# Аргентов С.Г. 22.03.23
# https://argentov.pro

# %% [markdown]
# _________

# %% [markdown]
# <h1>СОДЕРЖАНИЕ<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1.-Загрузка:-библиотек,-разработанных-функций,-данных" data-toc-modified-id="1.-Загрузка:-библиотек,-разработанных-функций,-данных-1">1. Загрузка: библиотек, разработанных функций, данных</a></span></li><li><span><a href="#2.-Подготовка-данных-для-обучения-модели-нейросети" data-toc-modified-id="2.-Подготовка-данных-для-обучения-модели-нейросети-2">2. Подготовка данных для обучения модели нейросети</a></span><ul class="toc-item"><li><span><a href="#2.1.-Исходные-условия-для-поиска-навыков-в-тексте-объявлений" data-toc-modified-id="2.1.-Исходные-условия-для-поиска-навыков-в-тексте-объявлений-2.1">2.1. Исходные условия для поиска навыков в тексте объявлений</a></span></li><li><span><a href="#2.2.-Преобразование-признаков-таргета-в-векторы" data-toc-modified-id="2.2.-Преобразование-признаков-таргета-в-векторы-2.2">2.2. Преобразование признаков таргета в векторы</a></span></li><li><span><a href="#2.3.-Преобразование-исходных-текстов-объявлений-в-векторы" data-toc-modified-id="2.3.-Преобразование-исходных-текстов-объявлений-в-векторы-2.3">2.3. Преобразование исходных текстов объявлений в векторы</a></span></li></ul></li><li><span><a href="#3.-Модель-нейронной-сети-LSTM" data-toc-modified-id="3.-Модель-нейронной-сети-LSTM-3">3. Модель нейронной сети LSTM</a></span><ul class="toc-item"><li><span><a href="#3.1.-Формирование-модели" data-toc-modified-id="3.1.-Формирование-модели-3.1">3.1. Формирование модели</a></span></li><li><span><a href="#3.2.-Обучение-модели" data-toc-modified-id="3.2.-Обучение-модели-3.2">3.2. Обучение модели</a></span></li></ul></li><li><span><a href="#4.-Прогноз-неросетью-данных-о-вакансиях" data-toc-modified-id="4.-Прогноз-неросетью-данных-о-вакансиях-4">4. Прогноз неросетью данных о вакансиях</a></span><ul class="toc-item"><li><span><a href="#4.1.-Оценка-качества-работы-нейронной-сети" data-toc-modified-id="4.1.-Оценка-качества-работы-нейронной-сети-4.1">4.1. Оценка качества работы нейронной сети</a></span></li><li><span><a href="#4.2.-Классификация-навыков,-определённых-моделью" data-toc-modified-id="4.2.-Классификация-навыков,-определённых-моделью-4.2">4.2. Классификация навыков, определённых моделью</a></span></li><li><span><a href="#4.3.-Загрузка-навыков-в-json-файл" data-toc-modified-id="4.3.-Загрузка-навыков-в-json-файл-4.3">4.3. Загрузка навыков в json-файл</a></span></li></ul></li></ul></div>

# %% [markdown]
# ___________________

# %% [markdown]
# # 1. Загрузка: библиотек, разработанных функций, данных

# %%
# Загружаем библиотеки для работы с нейронной сетью
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, MaxPooling1D, Dropout, LSTM, Bidirectional, SpatialDropout1D
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import utils

# %%
# Загружаем библиотеки для обработки и визуализации данных
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import multiprocessing
from multiprocessing import Pool, Manager
import datetime as dt

# %%
# Загружаем используемые функции
from package220323.preparation import *
from package220323.download import *
from package220323.visualization import *

# %%
# Загружаем датасет с исходными данными и разметкой
df = file_load('2023-01-01-2023-01-10.xlsx')
# Out:
# ... загружаем файл с данными датасета ...
# Источником данных является файл: 023-01-01-2023-01-10.xlsx
# Размер файла 1381016 байт
# В файле содержится 1 таблица:
#   - количество строк: 952
#   - количество столбцов: 78

# %% [markdown]
#  ____

# %% [markdown]
# # 2. Подготовка данных для обучения модели нейросети

# %% [markdown]
# ## 2.1. Исходные условия для поиска навыков в тексте объявлений

# %%
# Количесвто выявляемых навыков в тексет объявления
NUMBER_SKILLS = 93 # Приняты первые 93 навыка по популярности (в >1% объявлений)
# Максимальное количество слов, анализируемое в объявлении
NUMDER_WORDS = 12000
# Максимальная длина комментария
MAX_DESCRIPTION_LEN = 120

# %% [markdown]
# ## 2.2. Преобразование признаков таргета в векторы

# %%
# Сформируем схему разметки таргетов (навыков в объявлении)
# (первым элементом списка оставим 'id' для сохранения размерности датафрейма)
df_skills = labeled_skills(df)

# %%
# Удалим записи, в которых пропущена разметка таргетов (навыков в объявлении)
df = df.drop(index=df_skills[1], axis=0)
df_skills_ = df_skills[0].drop(index=df_skills[1], axis=0)

# %%
# Сформируем векторы таргетов с максимально востребованными компетенциями
target_vectors = skill_vectors(df, df_skills_, NUMBER_SKILLS)
y = target_vectors[0]

# %% [markdown]
# ## 2.3. Преобразование исходных текстов объявлений в векторы

# %%
# Обработаем датасет в мультипроцессорном режиме с замером времени
# (удалим из текста html-теги, неалфавитные символы, переведём в нижний регистр)

start_time = dt.datetime.now()
print('ВРЕМЯ СТАРТА РАСЧЁТА:', start_time, '\n')

# Запарралелим расчёты между доступными ядрами процессора:

# 1. рассчитываем количество ядер процесса, которые задействуем для вычислений
#    (уменьшаем на 1 ядро, которое оставляем на системные потребности)
n_cpu = multiprocessing.cpu_count() - 1
print('Количество доступных процессоров:', n_cpu)

# 2. Расчитаем размер обрабатываемого парралельно подмассива
val_sub = int(len(df)/n_cpu)
print('Размеры подмассивов:', val_sub, '\n')

# 3. Создаём менеджера парралельных процессов
#    и его пространство имён для обмена данными между процессами
if __name__ == '__main__':
    with Manager() as mng:
        ns = mng.Namespace()
        ns.dfs = mng.list()
        # 4. Делим датасет на составляющие,
        #    которые будут рассчитываться в парралельных процессах
        for i in range(n_cpu - 1):
            ns.dfs.append(df[val_sub*i:val_sub*(i+1)])
        ns.dfs.append(df[(n_cpu-1)*val_sub:])

        # 5. Запустим пул парралельных процессов вычислений
        #    и объединим результат в единый датафрейм
        with Pool(n_cpu) as p:
            df = pd.concat(list(p.map(lem_text, ns.dfs)), axis=0)

finish_time = dt.datetime.now()
print('\n\nВРЕМЯ ОКОНЧАНИЯ РАСЧЁТА:', finish_time)
print('ВРЕМЯ ВЫПОЛНЕНИЯ:', finish_time - start_time, '\n' * 2)
# Out:
# ВРЕМЯ СТАРТА РАСЧЁТА: 2023-03-29 03:33:36.036517
#
# Количество доступных процессоров: 7
# Размеры подмассивов: 112
#
#  Процесс 1054 отработал. Размер переработанного датасета (112, 79)
#  Процесс 1058 отработал. Размер переработанного датасета (112, 79)
#  Процесс 1055 отработал. Размер переработанного датасета (112, 79)
#  Процесс 1056 отработал. Размер переработанного датасета (112, 79)
#  Процесс 1057 отработал. Размер переработанного датасета (112, 79)
#  Процесс 1059 отработал. Размер переработанного датасета (112, 79)
#  Процесс 1060 отработал. Размер переработанного датасета (116, 79)
#
#
# ВРЕМЯ ОКОНЧАНИЯ РАСЧЁТА: 2023-03-29 03:34:36.719991
# ВРЕМЯ ВЫПОЛНЕНИЯ: 0:01:00.683474

# %%
# Создаём токенизатор
tokenizer = Tokenizer(num_words=NUMDER_WORDS)
# Обучаем токенизатор
tokenizer.fit_on_texts(df['normal_description'])
# Преобразуем текст в числовые представления
sequences = tokenizer.texts_to_sequences(df['normal_description'])

# %%
# Ограничим длинну описательной части объявления
X = pad_sequences(sequences, maxlen=MAX_DESCRIPTION_LEN)

# %%
# Разобъём датасет на тестовый и проверочный
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(X, y,
                                                    test_size = 0.33,
                                                    random_state = 42)

# %%
# Запишем индексы тестовой выборки для формирования json-файла
y_test_id = df[['id']].loc[y_test.index]

# %% [markdown]
# ____

# %% [markdown]
# # 3. Модель нейронной сети LSTM

# %% [markdown]
# ## 3.1. Формирование модели

# %%
# Создаём колбек для фиксации наилучшей модели
model_lstm_save_path = 'best_model_lstm.h5'
checkpoint_callback_lstm = ModelCheckpoint(model_lstm_save_path, 
                                      monitor='val_accuracy',
                                      save_best_only=True,
                                      verbose=1)

# %%
# Задаём структуру модели
model_lstm = Sequential()
model_lstm.add(Embedding(NUMDER_WORDS, 128, input_length=MAX_DESCRIPTION_LEN))
model_lstm.add(SpatialDropout1D(0.5))
model_lstm.add(LSTM(NUMBER_SKILLS*6, return_sequences=True))
model_lstm.add(LSTM(NUMBER_SKILLS*6))
model_lstm.add(Dense(NUMBER_SKILLS, activation='sigmoid'))
# Out:
# 2023-03-29 03:35:11.051753: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-03-29 03:35:11.053692: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-03-29 03:35:11.055170: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-03-29 03:35:11.513988: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-03-29 03:35:11.515971: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-03-29 03:35:11.517426: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Компилируем модель
model_lstm.compile(optimizer='adam', 
              loss='binary_crossentropy', 
              metrics=['accuracy', 'AUC'])

# %% [markdown]
# ## 3.2. Обучение модели

# %%
# Обучаем модель
history_lstm = model_lstm.fit(x_train, 
                              y_train, 
                              epochs=7,
                              batch_size=512,
                              validation_split=0.2,
                              callbacks=[checkpoint_callback_lstm])
# Out:
# Epoch 1/7
# 2023-03-29 03:35:15.143759: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-03-29 03:35:15.145564: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-03-29 03:35:15.147320: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-03-29 03:35:15.438597: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-03-29 03:35:15.440389: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-03-29 03:35:15.442233: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-03-29 03:35:17.025068: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-03-29 03:35:17.027824: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-03-29 03:35:17.029654: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-03-29 03:35:17.405910: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-03-29 03:35:17.409530: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-03-29 03:35:17.412697: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.0261 - auc: 0.5003
# 2023-03-29 03:35:30.326660: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-03-29 03:35:30.329858: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-03-29 03:35:30.332568: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-03-29 03:35:30.727673: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-03-29 03:35:30.730315: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-03-29 03:35:30.732188: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1: val_accuracy improved from -inf to 0.06604, saving model to best_model_lstm.h5
# 1/1 [==============================] - 18s 18s/step - loss: 0.6932 - accuracy: 0.0261 - auc: 0.5003 - val_loss: 0.6903 - val_accuracy: 0.0660 - val_auc: 0.5106
# Epoch 2/7
# 1/1 [==============================] - ETA: 0s - loss: 0.6903 - accuracy: 0.0689 - auc: 0.5224
# Epoch 2: val_accuracy improved from 0.06604 to 0.27358, saving model to best_model_lstm.h5
# 1/1 [==============================] - 12s 12s/step - loss: 0.6903 - accuracy: 0.0689 - auc: 0.5224 - val_loss: 0.6829 - val_accuracy: 0.2736 - val_auc: 0.5764
# Epoch 3/7
# 1/1 [==============================] - ETA: 0s - loss: 0.6828 - accuracy: 0.2755 - auc: 0.6038
# Epoch 3: val_accuracy improved from 0.27358 to 0.67925, saving model to best_model_lstm.h5
# 1/1 [==============================] - 11s 11s/step - loss: 0.6828 - accuracy: 0.2755 - auc: 0.6038 - val_loss: 0.6334 - val_accuracy: 0.6792 - val_auc: 0.6049
# Epoch 4/7
# 1/1 [==============================] - ETA: 0s - loss: 0.6328 - accuracy: 0.7102 - auc: 0.6266
# Epoch 4: val_accuracy did not improve from 0.67925
# 1/1 [==============================] - 9s 9s/step - loss: 0.6328 - accuracy: 0.7102 - auc: 0.6266 - val_loss: 0.3386 - val_accuracy: 0.6792 - val_auc: 0.5884
# Epoch 5/7
# 1/1 [==============================] - ETA: 0s - loss: 0.3368 - accuracy: 0.7102 - auc: 0.6092
# Epoch 5: val_accuracy did not improve from 0.67925
# 1/1 [==============================] - 9s 9s/step - loss: 0.3368 - accuracy: 0.7102 - auc: 0.6092 - val_loss: 0.2324 - val_accuracy: 0.6792 - val_auc: 0.5853
# Epoch 6/7
# 1/1 [==============================] - ETA: 0s - loss: 0.2288 - accuracy: 0.7102 - auc: 0.6068
# Epoch 6: val_accuracy did not improve from 0.67925
# 1/1 [==============================] - 9s 9s/step - loss: 0.2288 - accuracy: 0.7102 - auc: 0.6068 - val_loss: 0.1860 - val_accuracy: 0.6792 - val_auc: 0.6348
# Epoch 7/7
# 1/1 [==============================] - ETA: 0s - loss: 0.1820 - accuracy: 0.7102 - auc: 0.6581
# Epoch 7: val_accuracy did not improve from 0.67925
# 1/1 [==============================] - 9s 9s/step - loss: 0.1820 - accuracy: 0.7102 - auc: 0.6581 - val_loss: 0.1642 - val_accuracy: 0.6792 - val_auc: 0.6909

# %%
# Построим графики обучения модели
accuracy_graf(history_lstm.history)

# %% [markdown]
# # 4. Прогноз неросетью данных о вакансиях

# %% [markdown]
# ## 4.1. Оценка качества работы нейронной сети

# %%
# Загружаем модель
model_lstm.load_weights(model_lstm_save_path)

# %%
## Выводим оценку
model_lstm.evaluate(x_test, y_test, verbose=1)
# Out:
# 9/9 [==============================] - 4s 465ms/step - loss: 0.6336 - accuracy: 0.7471 - auc: 0.6254
# [0.6335914731025696, 0.7471264600753784, 0.6253595352172852]

# %% [markdown]
# ## 4.2. Классификация навыков, определённых моделью

# %%
# Формируем результат работы модели на тестовой выборке
model_result = model_lstm.predict(x_test)
# Out:
# 2023-03-29 03:37:04.390930: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-03-29 03:37:04.392866: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-03-29 03:37:04.394247: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-03-29 03:37:04.703536: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-03-29 03:37:04.705934: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-03-29 03:37:04.707597: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 9/9 [==============================] - 5s 477ms/step

# %%
# Формируем датафрейм для загрузки в json-файл
df_result = pd.DataFrame(data = model_result, columns=target_vectors[2])
res_id = y_test_id.copy()
res_id.reset_index(drop=True, inplace=True)
predict_matrix = pd.concat([res_id, df_result], axis=1)

# %%
# Формируем словарь для json-файла
res_skills = {elem: [] for elem in target_vectors[2]}
for i, row in predict_matrix.iterrows():
    for key, skill in row[1:].iteritems():
        if skill > 0.3:
            res_skills[key].append(str(predict_matrix.at[i, 'id']))
res_skills = {elem: res_skills[elem] for elem in res_skills
             if len(res_skills[elem]) != 0}

# %% [markdown]
# ## 4.3. Загрузка навыков в json-файл

# %%
# Формируем json-файл
with open('./Data/result.json', 'w') as f:
    json.dump(res_skills, f)
